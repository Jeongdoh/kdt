# %%
import csv
import matplotlib.pyplot as plt
import pandas as pd

import	platform
import	matplotlib.font_manager as	fm

# %%
df = pd.read_csv('국내공급자물가지수_전처리ver.csv', encoding='utf-8-sig')
df1 = pd.read_csv('소비자물가지수_전처리ver.csv', encoding='utf-8-sig')
producer_df = pd.read_csv('품목별_생산자물가지수.csv', encoding='cp949')
consumer_df = pd.read_csv('품목별_소비자물가지수.csv', encoding='cp949',header=1)
farm_df = pd.read_csv('농산물_소비자물가지수.csv', encoding='cp949',header=1)
slave_df=pd.read_csv('SW기술자_평균임금.csv', encoding='cp949')

# %% [markdown]
# ### 국내공급자물가지수

# %%
df.head()
df.dtypes
df['date'] = df['date'].astype('datetime64')
df['date'].dt.year
# Out:
# 0     2020
# 1     2020
# 2     2020
# 3     2020
# 4     2020
# 5     2020
# 6     2020
# 7     2020
# 8     2020
# 9     2020
# 10    2020
# 11    2020
# 12    2021
# 13    2021
# 14    2021
# 15    2021
# 16    2021
# 17    2021
# 18    2021
# 19    2021
# 20    2021
# 21    2021
# 22    2021
# 23    2021
# 24    2022
# 25    2022
# 26    2022
# 27    2022
# 28    2022
# 29    2022
# 30    2022
# 31    2022
# 32    2022
# 33    2022
# 34    2022
# 35    2022
# Name: date, dtype: int64

# %%
system_name = platform.system()
if	system_name == 'Windows':
    #	Windows	운영체제
    print('Windows	OS')
    plt.rc('font', family='Malgun Gothic')
elif system_name ==	'Darwin': # Mac OS
    print('Mac	OS')
    plt.rc('font', family='AppleGothic')
elif system_name ==	'Linux': # Linux
    print('Linux OS')
    path = '/usr/share/fonts/truetype/nanum/NanumMyeongjo.ttf'
    font_name =	fm.FontProperties(fname=path, size=12)
    plt.rc('font', family=font_name)
else:
    print("Not support")

x = range(0,len(df['index']))
plt.figure(dpi=100)
plt.bar(x,df['index'])
plt.title(f'국내공급자물가지수',size=11)
plt.ylim(90,130)
plt.xticks(x, df['date'], rotation=80)
plt.plot(kind= 'kde')

plt.show()
# Out:
# Windows	OS

# %%
date = []
point = []

df['date'] = pd.to_datetime(df['date'])
df['date'] = df['date'].dt.strftime('%Y/%m')

date = df['date'].tolist()
index = df['index'].tolist()
plt.figure(figsize=(30,15))
plt.plot(date, index,'-o')
plt.title('국내공급자 물가지수',size=20)
plt.xlabel('Date',size=7)
plt.xticks(rotation = 45)
plt.ylabel('Index',size=7)
plt.ylim([90, 130])
plt.axhline(y=100, color='g', linewidth=1)


for i in range(len(df['date'])):
    height = df['index'].iloc[i]
    plt.text(df['date'].iloc[i], height + 0.25, '%.1f' %height, ha='center', va='bottom', size = 15)

plt.show()

# %% [markdown]
# ### 소비자 물가 지수

# %%
df1
# Out:
#     Unnamed: 0        date   index
# 0            1  2020-01-01  100.09
# 1            2  2020-02-01  100.16
# 2            3  2020-03-01   99.94
# 3            4  2020-04-01   99.50
# 4            5  2020-05-01   99.44
# 5            6  2020-06-01   99.71
# 6            7  2020-07-01   99.63
# 7            8  2020-08-01  100.19
# 8            9  2020-09-01  100.74
# 9           10  2020-10-01  100.18
# 10          11  2020-11-01  100.09
# 11          12  2020-12-01  100.33
# 12          13  2021-01-01  101.04
# 13          14  2021-02-01  101.58
# 14          15  2021-03-01  101.84
# 15          16  2021-04-01  101.98
# 16          17  2021-05-01  102.05
# 17          18  2021-06-01  102.05
# 18          19  2021-07-01  102.26
# 19          20  2021-08-01  102.75
# 20          21  2021-09-01  103.17
# 21          22  2021-10-01  103.35
# 22          23  2021-11-01  103.87
# 23          24  2021-12-01  104.04
# 24          25  2022-01-01  104.69
# 25          26  2022-02-01  105.30
# 26          27  2022-03-01  106.06
# 27          28  2022-04-01  106.85
# 28          29  2022-05-01  107.56
# 29          30  2022-06-01  108.22
# 30          31  2022-07-01  108.74
# 31          32  2022-08-01  108.62
# 32          33  2022-09-01  108.93
# 33          34  2022-10-01  109.21
# 34          35  2022-11-01  109.10
# 35          36  2022-12-01  109.28
# 36          37  2023-01-01  110.11

# %%
date = []
point = []

df1['date'] = pd.to_datetime(df1['date'])
df1['date'] = df1['date'].dt.strftime('%Y/%m')

date = df1['date'].tolist()
index = df1['index'].tolist()
plt.figure(figsize=(30,15))
plt.plot(date, index,'-o')
plt.title('소비자 물가지수',size=20)
plt.xlabel('Date',size=7)
plt.xticks(rotation = 45)
plt.ylabel('Index',size=7)
plt.ylim([90, 130])
plt.axhline(y=100, color='g', linewidth=1)


for i in range(len(df1['date'])):
    height = df1['index'].iloc[i]
    plt.text(df1['date'].iloc[i], height + 0.25, '%.1f' %height, ha='center', va='bottom', size = 15)

plt.show()

# %% [markdown]
# ### 품목별 생산자 지수

# %%
producer_df
# Out:
#          시점  쌀 (2015=100)  보리쌀 (2015=100)  콩 (2015=100)  감자 (2015=100)  \
# 0   2020.01        120.22           67.35        129.88          73.59
# 1   2020.02        120.08           67.35        129.88          73.08
# 2   2020.03        119.87           67.35        129.88          78.16
# 3   2020.04        119.99           67.35        130.22         148.04
# 4   2020.05        120.06           67.35        130.74         149.62
# 5   2020.06        120.70           67.35        132.43          94.25
# 6   2020.07        120.96           67.35        132.99          82.15
# 7   2020.08        121.15           67.35        132.50         110.43
# 8   2020.09        121.89           67.35        134.74         116.11
# 9   2020.10        136.50           67.35        136.48         112.97
# 10  2020.11        136.60           67.35        146.27         119.96
# 11  2020.12        137.61           67.35        154.10         107.24
# 12  2021.01        138.17           67.35        154.42         110.65
# 13  2021.02        138.88           67.35        155.47         113.36
# 14  2021.03        139.92           67.35        158.40         110.04
# 15  2021.04        141.01           67.35        158.88          98.61
# 16  2021.05        141.31           67.35        159.11          90.23
# 17  2021.06        141.41           67.50        160.54          75.06
# 18  2021.07        141.31           67.71        163.15          81.95
# 19  2021.08        140.60           67.71        163.41         106.77
# 20  2021.09        137.28           67.71        163.52         114.36
# 21  2021.10        140.03           67.71        162.71         111.78
# 22  2021.11        134.98           67.71        160.20         123.39
# 23  2021.12        131.25           67.71        155.30         137.20
# 24  2022.01        128.44           68.12        148.93         136.58
# 25  2022.02        127.81           69.32        147.85         137.91
# 26  2022.03        125.83           69.32        148.00         151.95
# 27  2022.04        121.04           69.32        147.78         220.30
# 28  2022.05        117.76           69.32        150.50         197.62
# 29  2022.06        115.19           72.15        151.84         131.95
# 30  2022.07        112.30           76.28        151.53         131.27
# 31  2022.08        107.45           76.28        151.53         142.17
# 32  2022.09        103.12           76.28        151.53         142.83
# 33  2022.10        118.95           76.28        152.97         140.36
# 34  2022.11        118.39           76.28        147.21         150.93
# 35  2022.12        117.92           76.28        138.54         150.04
#
#     고구마 (2015=100)  배추 (2015=100)  시금치 (2015=100)  상추 (2015=100)  \
# 0            88.30         193.45           65.26         138.04
# 1            93.76         180.49           63.32          54.44
# 2           122.98         171.96           74.23          56.14
# 3           143.64         192.29           71.92          50.83
# 4           187.28         256.32           69.82          65.90
# 5           205.16         173.08          106.95          98.37
# 6           215.72         209.85          153.00         163.60
# 7           192.70         379.61          301.47         281.90
# 8           133.33         495.31          336.13         165.43
# 9           123.18         208.13           84.17          58.02
# 10          125.82         111.69           65.84          52.87
# 11          137.90          86.12           69.19          90.86
# 12          154.48         100.92          116.27         142.68
# 13          159.48         154.04          100.85          88.42
# 14          156.97         188.84           79.63          68.36
# 15          155.52         193.05           89.46          78.39
# 16          179.96         147.49          106.85          90.18
# 17          185.85         108.64          123.49         115.41
# 18          126.72         131.92          217.39         174.43
# 19          122.95         194.18          404.79         222.73
# 20          121.66         246.38          254.91         299.24
# 21          108.55         128.34          192.65         232.18
# 22          105.36         196.97          111.17          91.63
# 23          111.13         169.91           83.09          87.62
# 24          105.50         165.37          108.37         126.77
# 25          106.56         170.18          152.30          79.72
# 26          102.67         194.07          118.20          77.45
# 27          106.02         216.60           96.31          90.34
# 28          103.66         237.59          107.70          80.79
# 29          104.20         191.57          132.55         133.85
# 30           93.86         281.64          402.91         330.06
# 31           99.49         372.02          531.36         298.40
# 32           94.70         657.60          337.04         169.75
# 33           86.18         252.06          123.26          94.79
# 34           91.90         138.34           69.37          59.05
# 35          101.87         110.70           73.64         128.35
#
#     부추 (2015=100)  ...  피망 (2015=100)  사과 (2015=100)  배 (2015=100)  \
# 0          209.00  ...         181.63          56.66        105.99
# 1          169.78  ...         242.92          56.11        109.14
# 2          118.78  ...         115.36          57.55        115.67
# 3          104.80  ...          59.65          60.35        119.50
# 4           77.54  ...          65.21          86.20        136.72
# 5           63.33  ...         100.84          94.41        139.96
# 6           40.99  ...          73.90         104.77        138.84
# 7          215.93  ...         115.42         128.40        137.55
# 8          102.68  ...         287.87         128.40        169.17
# 9          113.19  ...         152.57          83.97        158.83
# 10         198.58  ...          81.54          80.17        168.73
# 11         113.53  ...          88.34          97.25        185.95
# 12         211.37  ...         176.94         100.01        195.01
# 13         162.55  ...         281.31         107.35        200.55
# 14         110.71  ...         206.38         103.75        204.68
# 15          82.68  ...         108.50         107.65        209.01
# 16          67.83  ...          79.15         109.53        222.97
# 17          62.76  ...         130.57         108.07        231.79
# 18          78.70  ...          59.52          97.48        260.76
# 19         116.30  ...          51.90          74.31        267.27
# 20         138.29  ...         122.57          74.31        120.07
# 21         140.38  ...          80.80          65.26        103.89
# 22         233.71  ...         150.75          57.26        114.55
# 23         151.42         157.03
# 24         149.25         156.53
# 25         151.13         156.62
# 26         151.86         155.37
# 27         152.93         154.28
# 28         154.65         154.14
# 29         154.37         153.86
# 30         153.99         153.86
# 31         150.66         153.86
# 32         143.56         152.96
# 33         140.64         152.21
# 34         137.10         150.42
# 35         135.64         145.21
#
# [36 rows x 35 columns]

# %%
consumer_df.columns
# Out:
# Index(['시점', '쌀', '현미', '찹쌀', '보리쌀', '콩', '땅콩', '혼식곡', '배추', '상추', '시금치',
#        '양배추', '미나리', '깻잎', '부추', '무', '열무', '당근', '감자', '고구마', '도라지', '콩나물',
#        '버섯', '오이', '풋고추', '호박', '가지', '토마토', '파', '양파', '마늘', '브로콜리', '고사리',
#        '파프리카', '생강', '사과', '배', '복숭아', '포도', '밤', '감', '귤', '오렌지', '참외', '수박',
#        '딸기', '바나나', '키위', '블루베리', '망고', '체리', '아보카도', '파인애플', '아몬드', '고춧가루',
#        '참깨', '인삼'],
#       dtype='object')

# %%
#쌀, 보리쌀, 콩, 배추, 상추, 마늘, 시금치, 사과, 배, 참깨

# %%
producer1=producer_df.iloc[:,[0,1,6,7,8,33]]
producer1.columns=['시점','쌀','배추','시금치','상추','참깨']
producer1.columns
producer1
# Out:
#          시점       쌀      배추     시금치      상추      참깨
# 0   2020.01  120.22  193.45   65.26  138.04   90.28
# 1   2020.02  120.08  180.49   63.32   54.44   90.71
# 2   2020.03  119.87  171.96   74.23   56.14   92.00
# 3   2020.04  119.99  192.29   71.92   50.83   93.82
# 4   2020.05  120.06  256.32   69.82   65.90   96.10
# 5   2020.06  120.70  173.08  106.95   98.37   96.99
# 6   2020.07  120.96  209.85  153.00  163.60   98.37
# 7   2020.08  121.15  379.61  301.47  281.90  102.15
# 8   2020.09  121.89  495.31  336.13  165.43  124.54
# 9   2020.10  136.50  208.13   84.17   58.02  142.45
# 10  2020.11  136.60  111.69   65.84   52.87  153.11
# 11  2020.12  137.61   86.12   69.19   90.86  161.03
# 12  2021.01  138.17  100.92  116.27  142.68  163.04
# 13  2021.02  138.88  154.04  100.85   88.42  164.60
# 14  2021.03  139.92  188.84   79.63   68.36  167.87
# 15  2021.04  141.01  193.05   89.46   78.39  167.86
# 16  2021.05  141.31  147.49  106.85   90.18  166.94
# 17  2021.06  141.41  108.64  123.49  115.41  167.81
# 18  2021.07  141.31  131.92  217.39  174.43  168.73
# 19  2021.08  140.60  194.18  404.79  222.73  163.16
# 20  2021.09  137.28  246.38  254.91  299.24  136.52
# 21  2021.10  140.03  128.34  192.65  232.18  137.36
# 22  2021.11  134.98  196.97  111.17   91.63  146.97
# 23  2021.12  131.25  169.91   83.09   87.62  151.42
# 24  2022.01  128.44  165.37  108.37  126.77  149.25
# 25  2022.02  127.81  170.18  152.30   79.72  151.13
# 26  2022.03  125.83  194.07  118.20   77.45  151.86
# 27  2022.04  121.04  216.60   96.31   90.34  152.93
# 28  2022.05  117.76  237.59  107.70   80.79  154.65
# 29  2022.06  115.19  191.57  132.55  133.85  154.37
# 30  2022.07  112.30  281.64  402.91  330.06  153.99
# 31  2022.08  107.45  372.02  531.36  298.40  150.66
# 32  2022.09  103.12  657.60  337.04  169.75  143.56
# 33  2022.10  118.95  252.06  123.26   94.79  140.64
# 34  2022.11  118.39  138.34   69.37   59.05  137.10
# 35  2022.12  117.92  110.70   73.64  128.35  135.64

# %%
date = []
point = []



producer1['시점']
time = producer1['시점']
producer1.set_index('시점')
# Out:
#               쌀      배추     시금치      상추      참깨
# 시점
# 2020.01  120.22  193.45   65.26  138.04   90.28
# 2020.02  120.08  180.49   63.32   54.44   90.71
# 2020.03  119.87  171.96   74.23   56.14   92.00
# 2020.04  119.99  192.29   71.92   50.83   93.82
# 2020.05  120.06  256.32   69.82   65.90   96.10
# 2020.06  120.70  173.08  106.95   98.37   96.99
# 2020.07  120.96  209.85  153.00  163.60   98.37
# 2020.08  121.15  379.61  301.47  281.90  102.15
# 2020.09  121.89  495.31  336.13  165.43  124.54
# 2020.10  136.50  208.13   84.17   58.02  142.45
# 2020.11  136.60  111.69   65.84   52.87  153.11
# 2020.12  137.61   86.12   69.19   90.86  161.03
# 2021.01  138.17  100.92  116.27  142.68  163.04
# 2021.02  138.88  154.04  100.85   88.42  164.60
# 2021.03  139.92  188.84   79.63   68.36  167.87
# 2021.04  141.01  193.05   89.46   78.39  167.86
# 2021.05  141.31  147.49  106.85   90.18  166.94
# 2021.06  141.41  108.64  123.49  115.41  167.81
# 2021.07  141.31  131.92  217.39  174.43  168.73
# 2021.08  140.60  194.18  404.79  222.73  163.16
# 2021.09  137.28  246.38  254.91  299.24  136.52
# 2021.10  140.03  128.34  192.65  232.18  137.36
# 2021.11  134.98  196.97  111.17   91.63  146.97
# 2021.12  131.25  169.91   83.09   87.62  151.42
# 2022.01  128.44  165.37  108.37  126.77  149.25
# 2022.02  127.81  170.18  152.30   79.72  151.13
# 2022.03  125.83  194.07  118.20   77.45  151.86
# 2022.04  121.04  216.60   96.31   90.34  152.93
# 2022.05  117.76  237.59  107.70   80.79  154.65
# 2022.06  115.19  191.57  132.55  133.85  154.37
# 2022.07  112.30  281.64  402.91  330.06  153.99
# 2022.08  107.45  372.02  531.36  298.40  150.66
# 2022.09  103.12  657.60  337.04  169.75  143.56
# 2022.10  118.95  252.06  123.26   94.79  140.64
# 2022.11  118.39  138.34   69.37   59.05  137.10
# 2022.12  117.92  110.70   73.64  128.35  135.64

# %%
f  = list(producer1.columns)
f.pop(0)
# Out:
# '시점'

# %%
date = producer1['시점'].tolist()
y = ['쌀','배추','시금치','상추','참깨']
x = range(0,len(producer1['쌀']))
plt.figure(figsize=(30,15))

for i in y:
    plt.plot(producer1[i],'-o')
# plt.plot(index,'-o')
plt.title('품목별 생산자 물가지수',size=20)
plt.xlabel('Date',size=7)
plt.axhline(y=100, color='g', linewidth=1)
plt.xticks(range(len(producer1.index)),labels=list(time),rotation=45)

plt.legend(f)

# %% [markdown]
# ### 품목별 소비자 물가지수

# %%
consumer1=consumer_df.iloc[:,[0,1,8,10,9,55]]
consumer1
# Out:
#          시점       쌀      배추     시금치      상추      참깨
# 2021.04  110.08   92.16   66.45   85.83  101.25
# 2021.05  110.65   78.30   78.75   86.22  101.27
# 2021.06  110.73   69.02   87.88   97.18  101.42
# 2021.07  111.17   70.59  117.19  111.20  101.43
# 2021.08  111.20   89.57  229.65  144.59  101.53
# 2021.09  109.91  108.11  205.47  201.08  101.54
# 2021.10  107.10   84.16  126.96  125.01  101.67
# 2021.11  106.80   87.14  118.49  134.21  102.03
# 2021.12  105.63   87.47   89.34   93.22  103.85
# 2022.01  103.89   87.82   96.61  107.84  105.84
# 2022.02  102.87   88.07  108.70  101.21  107.16
# 2022.03  101.90   89.52   97.84   86.35  108.28
# 2022.04   99.94   99.28   85.38   91.21  108.85
# 2022.05   98.23   97.11   90.61   85.71  108.57
# 2022.06   96.77   93.53  102.30   87.19  108.76
# 2022.07   95.23  121.93  199.93  181.39  108.79
# 2022.08   92.80  159.40  263.91  179.79  110.32
# 2022.09   90.34  210.79  259.07  172.65  111.29
# 2022.10   91.08  145.04  129.06  103.27  114.63
# 2022.11   96.16   78.42   94.44   88.20  119.38
# 2022.12   95.76   62.31   77.92   89.76  120.36
# 2023.01   94.26   64.35   96.96  136.64  121.06

# %%
z  = list(consumer1.columns)
z.pop(0)
# Out:
# '시점'

# %%
consumer1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 37 entries, 0 to 36
# Data columns (total 6 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   시점      37 non-null     float64
#  1   쌀       37 non-null     float64
#  2   배추      37 non-null     float64
#  3   시금치     37 non-null     float64
#  4   상추      37 non-null     float64
#  5   참깨      37 non-null     float64
# dtypes: float64(6)
# memory usage: 1.9 KB

# %%
date = consumer1['시점'].tolist()
y = ['쌀','배추','시금치','상추','참깨']
x = range(0,len(consumer1['쌀']))
plt.figure(figsize=(30,15))

for i in y:
    plt.plot(consumer1[i],'-o')
# plt.plot(index,'-o')
plt.title('품목별 소비자 물가지수',size=20)
plt.xlabel('Date',size=7)
plt.axhline(y=100, color='g', linewidth=1)
plt.xticks(range(len(consumer1.index)),labels=list(time),rotation=45)

plt.legend(z)

# %% [markdown]
# ### 농산물 물가지수

# %%
farm_df = pd.read_csv('농산물_소비자물가지수.csv', encoding='cp949',header=1)

# %%
farm_df
# Out:
#          시점      전국
# 0   2020.01   96.43
# 1   2020.02   94.97
# 2   2020.03   96.37
# 3   2020.04   94.17
# 4   2020.05   93.46
# 5   2020.06   92.53
# 6   2020.07   95.55
# 7   2020.08  104.79
# 8   2020.09  114.73
# 9   2020.10  113.32
# 10  2020.11  101.81
# 11  2020.12  101.87
# 12  2021.01  107.46
# 13  2021.02  114.47
# 14  2021.03  113.94
# 15  2021.04  110.80
# 16  2021.05  107.39
# 17  2021.06  103.58
# 18  2021.07  103.58
# 19  2021.08  107.10
# 20  2021.09  111.43
# 21  2021.10  105.79
# 22  2021.11  106.86
# 23  2021.12  107.38
# 24  2022.01  112.39
# 25  2022.02  111.82
# 26  2022.03  109.64
# 27  2022.04  109.20
# 28  2022.05  106.73
# 29  2022.06  105.26
# 30  2022.07  112.37
# 31  2022.08  118.21
# 32  2022.09  121.09
# 33  2022.10  113.46
# 34  2022.11  104.71
# 35  2022.12  105.62
# 36  2023.01  112.15

# %%
list(farm_df['시점'])
# Out:
# [2020.01,
#  2020.02,
#  2020.03,
#  2020.04,
#  2020.05,
#  2020.06,
#  2020.07,
#  2020.08,
#  2020.09,
#  2020.1,
#  2020.11,
#  2020.12,
#  2021.01,
#  2021.02,
#  2021.03,
#  2021.04,
#  2021.05,
#  2021.06,
#  2021.07,
#  2021.08,
#  2021.09,
#  2021.1,
#  2021.11,
#  2021.12,
#  2022.01,
#  2022.02,
#  2022.03,
#  2022.04,
#  2022.05,
#  2022.06,
#  2022.07,
#  2022.08,
#  2022.09,
#  2022.1,
#  2022.11,
#  2022.12,
#  2023.01]

# %%
farm_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 37 entries, 0 to 36
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   시점      37 non-null     float64
#  1   전국      37 non-null     float64
# dtypes: float64(2)
# memory usage: 720.0 bytes

# %%
date = []
point = []



date = farm_df['시점'].tolist()
index = farm_df['전국'].tolist()
x = range(len(date))
plt.figure(figsize=(30,15))
plt.plot(x, index,'-o')
plt.title('농산물 물가지수',size=20)
plt.xlabel('Date',size=7)
plt.xticks(x,date, rotation = 45)
plt.ylabel('농산물지수',size=7)
plt.ylim([90, 130])
plt.axhline(y=100, color='g', linewidth=1)
farm_df['전국'] = farm_df['전국'].astype('O')
for i in range(len(farm_df['시점'])):
    height = farm_df['전국'].iloc[i]
    plt.text(i, height + 0.25, height, ha='center', va='bottom', size = 15)

# %%
slave_df['시점']
time_slave = slave_df['시점']
slave_df.set_index('시점')
# Out:
#        IT기획자  IT컨설턴트   업무분석가  데이터분석가  SW 아키텍트  데이터 아키텍트  응용SW 개발자  시스템SW 개발자  \
# 시점
# 2019  403081  437900  501090  335799   389104    399985    305985     247970
# 2020  388724  458818  532243  347670   421761    437063    323174     253051
# 2021  360307  484732  548550  323184   448240    414770    306034     238787
#
#       임베디드SW 개발자  데이터베이스 운용자  IT시스템운용자  IT지원 기술자  IT서비스 기획자  IT기술영업  IT품질관리자  \
# 시점
# 2019      271214      274324    278605    183743     383295  376746   402554
# 2020      277998      298254    284286    203918     441052  372497   438304
# 2021      261291      243285    297180    191065     347311  341672   424780
#
#        IT테스터    IT감리    IT감사  IT교육강사
# 시점
# 2019  198611  340109  398085  321017
# 2020  207793  391741  274802  257614
# 2021  200136  424481  236877  279165

# %%
p  = list(slave_df.columns)
p.pop(0)
# Out:
# '시점'

# %%
date = []
point = []


date = slave_df['시점'].tolist()
y = ['IT기획자','IT컨설턴트','업무분석가','데이터분석가','SW 아키텍트','데이터 아키텍트','응용SW 개발자','시스템SW 개발자','임베디드SW 개발자',\
    '데이터베이스 운용자','IT시스템운용자','IT지원 기술자','IT서비스 기획자','IT기술영업','IT품질관리자','IT테스터','IT감리','IT감사','IT교육강사']

x = range(0,len(slave_df['IT기획자']))
plt.figure(figsize=(30,15))

for i in y:
    plt.plot(slave_df[i],'-o')
# plt.plot(index,'-o')
plt.title('IT 분야 임금 현황표',size=20)
plt.xlabel('시점',size=7)
plt.axhline(y=100, color='g', linewidth=1)
plt.xticks(range(len(slave_df.index)),labels=list(time_slave),rotation=45)

plt.legend(p)
