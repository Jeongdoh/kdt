# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
pd.options.display.max_rows = None

# %%
wiki = pd.read_html('https://en.wikipedia.org/wiki/List_of_countries_and_dependencies_by_population#Sovereign_states_and_dependencies_by_population')
wiki = wiki[0]
wiki = wiki.loc[1:100, ['Rank', 'Country / Dependency', 'Population']]
list = wiki['Population']
nums = list['Numbers']
numslist = nums.tolist()
y = numslist

flags = [2, 4, 3, 2, 2, 2, 4, 2, 3, 3,
         2, 4, 4, 4, 2, 3, 3, 2, 3, 3,
         3, 3, 4, 6, 3, 4, 4, 3, 3, 4,
         4, 3, 4, 5, 4, 2, 2, 2, 2, 4,
         2, 3, 2, 3, 2, 4, 5, 4, 3, 3,
         4, 3, 3, 3, 3, 3, 3, 3, 4, 4,
         3, 3, 3, 2, 4, 3, 3, 3, 2, 3,
         3, 3, 5, 6, 4, 3, 3, 3, 3, 2,
         7, 3, 4, 3, 6, 3, 2, 2, 6, 4,
         3, 2, 2, 4, 4, 3, 4, 2, 2, 3]
x = flags

df = pd.DataFrame({'Flag Colors':x, 'Population':y})

plt.plot(x, y, 'go')
plt.show()
