# %%
# 목적:
# 신용 카드 사용자 데이터를 보고 사용자의 대금 연체 정도를 예측하는 알고리즘 개발

# 데이터 변수 설명:
# https://www.dacon.io/competitions/official/235713/talkboard/402821

# %%
import numpy as np
import pandas as pd

# %%
train = pd.read_csv('data\\train.csv')
test = pd.read_csv('data\\test.csv')

# %%
train.info()
train.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 26457 entries, 0 to 26456
# Data columns (total 20 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   index          26457 non-null  int64
#  1   gender         26457 non-null  object
#  2   car            26457 non-null  object
#  3   reality        26457 non-null  object
#  4   child_num      26457 non-null  int64
#  5   income_total   26457 non-null  float64
#  6   income_type    26457 non-null  object
#  7   edu_type       26457 non-null  object
#  8   family_type    26457 non-null  object
#  9   house_type     26457 non-null  object
#  10  DAYS_BIRTH     26457 non-null  int64
#  11  DAYS_EMPLOYED  26457 non-null  int64
#  12  FLAG_MOBIL     26457 non-null  int64
#  13  work_phone     26457 non-null  int64
#  14  phone          26457 non-null  int64
#  15  email          26457 non-null  int64
#  16  occyp_type     18286 non-null  object
# ...

# %%
train.describe()
# Out:
#               index     child_num  income_total    DAYS_BIRTH  DAYS_EMPLOYED  \
# count  26457.000000  26457.000000  2.645700e+04  26457.000000   26457.000000
# mean   13228.000000      0.428658  1.873065e+05 -15958.053899   59068.750728
# std     7637.622372      0.747326  1.018784e+05   4201.589022  137475.427503
# min        0.000000      0.000000  2.700000e+04 -25152.000000  -15713.000000
# 25%     6614.000000      0.000000  1.215000e+05 -19431.000000   -3153.000000
# 50%    13228.000000      0.000000  1.575000e+05 -15547.000000   -1539.000000
# 75%    19842.000000      1.000000  2.250000e+05 -12446.000000    -407.000000
# max    26456.000000     19.000000  1.575000e+06  -7705.000000  365243.000000
#
#        FLAG_MOBIL    work_phone         phone         email   family_size  \
# count     26457.0  26457.000000  26457.000000  26457.000000  26457.000000
# mean          1.0      0.224742      0.294251      0.091280      2.196848
# ...

# %%
test.info()
test.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 19 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   index          10000 non-null  int64
#  1   gender         10000 non-null  object
#  2   car            10000 non-null  object
#  3   reality        10000 non-null  object
#  4   child_num      10000 non-null  int64
#  5   income_total   10000 non-null  float64
#  6   income_type    10000 non-null  object
#  7   edu_type       10000 non-null  object
#  8   family_type    10000 non-null  object
#  9   house_type     10000 non-null  object
#  10  DAYS_BIRTH     10000 non-null  int64
#  11  DAYS_EMPLOYED  10000 non-null  int64
#  12  FLAG_MOBIL     10000 non-null  int64
#  13  work_phone     10000 non-null  int64
#  14  phone          10000 non-null  int64
#  15  email          10000 non-null  int64
#  16  occyp_type     6848 non-null   object
# ...

# %%
test.describe()
# Out:
#              index     child_num  income_total    DAYS_BIRTH  DAYS_EMPLOYED  \
# count  10000.00000  10000.000000  1.000000e+04  10000.000000   10000.000000
# mean   31456.50000      0.434700  1.850433e+05 -16020.466400   59776.690400
# std     2886.89568      0.729102  1.015398e+05   4197.672887  138121.224504
# min    26457.00000      0.000000  2.700000e+04 -25152.000000  -15661.000000
# 25%    28956.75000      0.000000  1.215000e+05 -19483.250000   -3153.000000
# 50%    31456.50000      0.000000  1.575000e+05 -15606.000000   -1577.000000
# 75%    33956.25000      1.000000  2.250000e+05 -12539.000000    -410.000000
# max    36456.00000      5.000000  1.575000e+06  -7489.000000  365243.000000
#
#        FLAG_MOBIL    work_phone         phone         email   family_size  \
# count     10000.0  10000.000000  10000.000000  10000.000000  10000.000000
# mean          1.0      0.227600      0.296300      0.085600      2.202700
# ...

# %%
train.isnull().sum()
# Out:
# index               0
# gender              0
# car                 0
# reality             0
# child_num           0
# income_total        0
# income_type         0
# edu_type            0
# family_type         0
# house_type          0
# DAYS_BIRTH          0
# DAYS_EMPLOYED       0
# FLAG_MOBIL          0
# work_phone          0
# phone               0
# email               0
# occyp_type       8171
# family_size         0
# begin_month         0
# credit              0
# dtype: int64

# %%
test.isnull().sum()
# Out:
# index               0
# gender              0
# car                 0
# reality             0
# child_num           0
# income_total        0
# income_type         0
# edu_type            0
# family_type         0
# house_type          0
# DAYS_BIRTH          0
# DAYS_EMPLOYED       0
# FLAG_MOBIL          0
# work_phone          0
# phone               0
# email               0
# occyp_type       3152
# family_size         0
# begin_month         0
# dtype: int64

# %%
train = train.drop('occyp_type', axis = 1)
test = test.drop('occyp_type', axis = 1)

# %%
data = train[['child_num', 'income_total', 'family_size']].to_numpy()
target = train['credit'].to_numpy()

# %%
data
# Out:
# array([[0.000e+00, 2.025e+05, 2.000e+00],
#        [1.000e+00, 2.475e+05, 3.000e+00],
#        [0.000e+00, 4.500e+05, 2.000e+00],
#        ...,
#        [0.000e+00, 2.925e+05, 2.000e+00],
#        [0.000e+00, 1.710e+05, 1.000e+00],
#        [0.000e+00, 8.100e+04, 2.000e+00]])

# %%
target
# Out:
# array([1., 1., 2., ..., 2., 2., 2.])

# %%
from sklearn.model_selection import train_test_split
train_input, test_input, train_target, test_target = train_test_split(
    data, target, test_size = 0.2, random_state = 42)

# %%
print(train_input.shape, test_input.shape)
# Out:
# (21165, 3) (5292, 3)

# %%
from sklearn.preprocessing import StandardScaler
ss = StandardScaler()
ss.fit(train_input)
train_scaled = ss.transform(train_input)
test_scaled = ss.transform(test_input)

# %%
from sklearn.linear_model import LogisticRegression
lr = LogisticRegression()
lr.fit(train_scaled, train_target)
print(lr.score(train_scaled, train_target))
print(lr.score(test_scaled, test_target))
# Out:
# 0.6420033073470351
# 0.6386999244142101

# %%
dfcoef = pd.DataFrame(lr.coef_)
dfcoef
# Out:
#           0         1         2
# 0 -0.066929  0.034357  0.047714
# 1  0.096113 -0.055117 -0.093112
# 2 -0.029184  0.020759  0.045398

# %%
dfcept = pd.DataFrame(lr.intercept_)
dfcept
# Out:
#           0
# 0 -0.776387
# 1 -0.112499
# 2  0.888886

# %%
from sklearn.tree import DecisionTreeClassifier
dt = DecisionTreeClassifier(random_state = 42)
dt.fit(train_scaled, train_target)
print(dt.score(train_scaled, train_target))
print(dt.score(test_scaled, test_target))
# Out:
# 0.6526340656744626
# 0.6326530612244898

# %%
# import matplotlib.pyplot as plt
# from sklearn.tree import plot_tree
# plt.figure(figsize = (10, 7))
# plot_tree(dt)
# plt.show()

# %%
s = pd.read_csv('C:\\Users\\1\\Desktop\\Desktop\\DACON\\card\\data\\sample_submission.csv')
s = pd.DataFrame(s)
s['0'] = dfcoef[0]
s['1'] = dfcoef[1]
s['2'] = dfcoef[2]

# %%
s.to_csv('submission_lr.csv', index = False)
